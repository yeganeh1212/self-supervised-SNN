# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(training_data, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
# !pip install lightly

# %%
# !python --version
# Out:
# Python 3.9.16

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pytorch_lightning as pl
import torch
import torch.nn as nn
import torchvision
from PIL import Image
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize

from lightly.data import LightlyDataset, SimCLRCollateFunction, collate

# %%
num_workers = 8
batch_size = 256
seed = 1
max_epochs = 20
input_size = 128
num_ftrs = 32

# %%
collate_fn = SimCLRCollateFunction(input_size=input_size, vf_prob=0.5, rr_prob=0.5)

# %%
test_transforms = torchvision.transforms.Compose(
    [ torchvision.transforms.Resize((input_size, input_size)),torchvision.transforms.ToTensor(), torchvision.transforms.Normalize( 
        mean=collate.imagenet_normalize["mean"], std=collate.imagenet_normalize["std"],),
    ]
)

# %%
dataset_train_simclr = LightlyDataset(training_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dataset_train_simclr = LightlyDataset(training_data)
#
# File /usr/local/lib/python3.9/dist-packages/lightly/data/dataset.py:164, in LightlyDataset.__init__(self, input_dir, transform, index_to_filename, filenames, tqdm_args, num_workers_video_frame_counting)
#     161     is_valid_file = None
#     163 if self.input_dir is not None:
# --> 164     self.dataset = _load_dataset_from_folder(
#     165         self.input_dir,
#     166         transform,
#     167         is_valid_file=is_valid_file,
#     168         tqdm_args=tqdm_args,
#     169         num_workers_video_frame_counting=num_workers_video_frame_counting,
#     170     )
#     171 elif transform is not None:
#     172     raise ValueError(
#     173         "transform must be None when input_dir is None but is " f"{transform}",
# ...
